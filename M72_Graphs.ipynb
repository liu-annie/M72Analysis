# %%
drive_path = 'c:/'
import numpy as np
import pandas as pd
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
GSize=pd.read_csv("C:\Users\Annie\Documents\Data\Data\Glomerulus Size\Glomerulus_Size_Summary.csv")
GSize.keys()
# Out:
# Index([u'Ctrl_L', u'Mint_L', u'Hex_L', u'Ctrl_M', u'Mint_M', u'Hex_M'], dtype='object')

# %%
tmp=pd.melt(GSize)

# %%
sns.boxplot(GSize);
# Out:
# C:\Users\Annie\Anaconda2\lib\site-packages\seaborn\categorical.py:2171: UserWarning: The boxplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(data=GSize, jitter=True);

# %%
sns.swarmplot(data=GSize);

# %%
GSizeN=pd.read_csv("C:\Users\Annie\Documents\Data\Data\Glomerulus Size\Glomerulus_Size_Summary_Organized.csv")
GSizeN.keys()
# Out:
# Index([u'Ctrl - L', u'Ctrl - M', u'Mint - L', u'Mint - M', u'Hexanal - L',
#        u'Hexanal - M'],
#       dtype='object')

# %%
GSizeN
# Out:
#    Ctrl - L  Ctrl - M  Mint - L  Mint - M  Hexanal - L  Hexanal - M
# 0  108220.0     92208    217650     61484      98324.0     168270.0
# 1  105782.0     80582    192670     29352     126332.0     124908.0
# 2   67824.0    109220    182764    150532      68882.0     148278.0
# 3  161486.0     96142    153084    214342     129416.0     159546.0
# 4  108522.0    114994    199362    227964     169010.0      47702.0
# 5   63248.0     85754    252980    214816     113442.0      28110.0
# 6   76132.0     89502    199270    217390      51424.0      59436.0
# 7   63380.0     51780    208956    179022          NaN          NaN
# 8   55038.0     73808    173410    146164          NaN          NaN
# 9       NaN     70820    153402    163824          NaN          NaN

# %%
sns.boxplot(GSizeN);

# %%
sns.stripplot(data=GSizeN);

# %%
fig,ax=
sns.swarmplot(data=GSizeN);

# %%
sns.categorical()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-d950b1310c24> in <module>()
# ----> 1 sns.categorical()
#
# TypeError: 'module' object is not callable
